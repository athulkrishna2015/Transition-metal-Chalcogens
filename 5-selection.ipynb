# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/jupyter/2D/predict/MnXn.csv')
df
# Out:
#     formula    target
# 0      Sc2S  2.112843
# 1     Sc2Se  1.882968
# 2     Sc2Te  1.210932
# 3       Y2O  2.551786
# 4       Y2S  1.935714
# ..      ...       ...
# 554  Ru2Te7  0.647381
# 555   Os2O7  1.750264
# 556   Os2S7  1.520843
# 557  Os2Se7  0.944705
# 558  Os2Te7  0.705274
#
# [559 rows x 2 columns]

# %%
df_condition = df[(df['target'] < 1.8) & (df["target"] > 1.0)]
display(df_condition)
# Out:
#     formula    target
# 2     Sc2Te  1.210932
# 6      Y2Te  1.362950
# 10    La2Te  1.548127
# 11     Ti2O  1.328340
# 12     Ti2S  1.180284
# ..      ...       ...
# 549  Fe2Se7  1.480425
# 552   Ru2S7  1.605042
# 553  Ru2Se7  1.045522
# 555   Os2O7  1.750264
# 556   Os2S7  1.520843
#
# [223 rows x 2 columns]
