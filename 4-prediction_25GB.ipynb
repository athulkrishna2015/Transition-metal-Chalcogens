# %%
# !pip install CBFV
# !pip install pandas-Profiling -U
# Out:
# ...
#      |████████████████████████████████| 539 kB 5.1 MB/s
# ...

# %%
import os
import pandas as pd
# from pandas_profiling import ProfileReport
from sklearn.preprocessing import StandardScaler
# from sklearn.preprocessing import normalize

from CBFV.composition import generate_features

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from joblib import dump, load
#load model
model = load('/content/drive/MyDrive/jupyter/2D/save_model/oliynyk_ExtraTreesRegressor_full_HPO.joblib')

# %%
# !python MX1nX2nX3n.py > MX1nX2nX3n.csv

# %%
# PATH = os.getcwd()
# data_path = os.path.join(PATH, '/content/drive/MyDrive/jupyter/2D/data/MX1nX2n.csv')
df = pd.read_csv('MX1nX2nX3n.csv')

df
# Out:
#            ScO1S1Se1
# 0          ScO1S1Se2
# 1          ScO1S1Se3
# 2          ScO1S1Se4
# 3          ScO1S1Se5
# 4          ScO1S1Se6
# ...              ...
# 3499194  CnLv9Po9Te5
# 3499195  CnLv9Po9Te6
# 3499196  CnLv9Po9Te7
# 3499197  CnLv9Po9Te8
# 3499198  CnLv9Po9Te9
#
# [3499199 rows x 1 columns]

# %%
df['target'] = 0
# df.head()
df.columns = ['formula','target']
# df.head()

# %%
X_unscaled, y, formulae, skipped = generate_features(df, elem_prop='oliynyk', drop_duplicates=False, extend_features=False, sum_feat=True)
# Out:
# Processing Input Data: 100%|██████████| 3499199/3499199 [03:54<00:00, 14898.59it/s]
# 	Featurizing Compositions...
# Assigning Features...: 100%|██████████| 3499199/3499199 [06:51<00:00, 8498.33it/s]
# NOTE: Your data contains formula with exotic elements. These were skipped.

# %%
scaler = StandardScaler()

X = scaler.fit_transform(X_unscaled)

# %%
y_predict = model.predict(X)
# y_predict

# %%
df['target'] = y_predict
df.sort_values(by=['target'], ascending=False)

# %%
out_path = os.path.join(PATH, '/content/drive/MyDrive/jupyter/2D/predict/MX1nX2nX3n.csv')
df.to_csv(out_path, index=False)
