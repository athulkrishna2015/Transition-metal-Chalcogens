# %%
# !pip install CBFV
# # !pip install pandas-Profiling -U

# %%
import os
import pandas as pd
# from pandas_profiling import ProfileReport
from sklearn.preprocessing import StandardScaler
# from sklearn.preprocessing import normalize

from CBFV.composition import generate_features

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from joblib import dump, load
#load model
model = load('/content/drive/MyDrive/jupyter/2D/save_model/oliynyk_ExtraTreesRegressor_full_HPO.joblib')

# %%
# !python Metal_chal_all.py > '/content/drive/MyDrive/jupyter/2D/data/Metal_chal_all.csv'
# Out:
# Traceback (most recent call last):
#   File "Metal_chal_all.py", line 73, in <module>
#     for n4 in range(6):
# KeyboardInterrupt

# %%
PATH = os.getcwd()
data_path = os.path.join(PATH, '/content/drive/MyDrive/jupyter/2D/data/Metal_chal_all.py')
df = pd.read_csv(data_path)

df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-fc3bc479cfd7> in <module>()
#       1 PATH = os.getcwd()
#       2 data_path = os.path.join(PATH, '/content/drive/MyDrive/jupyter/2D/data/Metal_chal_all.py')
# ----> 3 df = pd.read_csv(data_path)
#       4
#       5 df
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
# profile = ProfileReport(df, title="Pandas Profiling Report")
# profile.to_notebook_iframe()

# %%
df['target'] = 0
# df.head()
df.columns = ['formula','target']
df.head()
# Out:
#   formula  target
# 0    Sc2S       0
# 1   Sc2Se       0
# 2   Sc2Te       0
# 3     Y2O       0
# 4     Y2S       0

# %%
X_unscaled, y, formulae, skipped = generate_features(df, elem_prop='oliynyk', drop_duplicates=False, extend_features=False, sum_feat=True)
# Out:
# Processing Input Data: 100%|██████████| 559/559 [00:00<00:00, 14289.82it/s]
# 	Featurizing Compositions...
# Assigning Features...: 100%|██████████| 559/559 [00:00<00:00, 9695.03it/s]
# 	Creating Pandas Objects...

# %%
scaler = StandardScaler()

X = scaler.fit_transform(X_unscaled)

# %%
y_predict = model.predict(X)
# y_predict

# %%
df['target'] = y_predict
df.sort_values(by=['target'], ascending=False)
# Out:
#     formula    target
# 243    Y2O3  3.724919
# 239   Sc2O3  3.723382
# 119     ScO  3.426221
# 247   La2O3  3.306332
# 123      YO  2.984829
# ..      ...       ...
# 30    Nb2Te  0.417632
# 53    Tc2Se  0.398115
# 58    Re2Te  0.378782
# 54    Tc2Te  0.367168
# 34    Ta2Te  0.335194
#
# [559 rows x 2 columns]

# %%
out_path = os.path.join(PATH, '/content/drive/MyDrive/jupyter/2D/predict/MnXn.csv')
df.to_csv(out_path, index=False)
